# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.70-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.70-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.6/862.6 kB 21.9 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 21.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 ultralytics-8.2.70 ultralytics-thop-2.0.0

# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.26)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.7-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 12.0 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 11.5 MB/s eta 0:00:00
# Downloading sounddevice-0.4.7-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.4 which is incompatible.
# Successfully installed mediapipe-0.10.14 protobuf-4.25.4 sounddevice-0.4.7

# %%
import cv2
import os
import pandas as pd
from ultralytics import YOLO
import mediapipe as mp
from moviepy.editor import VideoFileClip

# YOLOv8 모델 로드 (YOLOv8s 모델을 예제로 사용)
model = YOLO('yolov8s.pt')

# MediaPipe 포즈 추정기 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# 비디오 파일 경로와 타임스탬프 정보를 딕셔너리 형태로 저장
directories = {
    'theft': '/content/drive/MyDrive/DL/output_all/data_2/절도'
}

# 결과를 저장할 경로 설정
output_base_dir = '/content/drive/MyDrive/DL/output_all/mediapipe/processed_videos'
csv_output_base_dir = '/content/drive/MyDrive/DL/output_all/mediapipe/processed_csvs'

# 저장할 디렉토리가 없으면 생성
os.makedirs(output_base_dir, exist_ok=True)
os.makedirs(csv_output_base_dir, exist_ok=True)

def process_frame(frame, boxes):
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
        conf = box.conf[0].cpu().numpy()
        cls = box.cls[0].cpu().numpy()
        label = model.names[int(cls)]

        if label == 'person':
            person_crop = frame[int(y1):int(y2), int(x1):int(x2)]
            person_rgb = cv2.cvtColor(person_crop, cv2.COLOR_BGR2RGB)
            results_pose = pose.process(person_rgb)

            if results_pose.pose_landmarks:
                mp.solutions.drawing_utils.draw_landmarks(person_crop, results_pose.pose_landmarks, mp_pose.POSE_CONNECTIONS)
                # 랜드마크 좌표 저장
                landmarks = results_pose.pose_landmarks.landmark
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)  # 바운딩 박스 그리기
                return [(lm.x, lm.y, lm.z, lm.visibility) for lm in landmarks]  # 랜드마크 추가
    return []

for behavior, directory in directories.items():
    print(f"Processing {behavior} videos...")

    for filename in os.listdir(directory):
        video_filepath = os.path.join(directory, filename)

        # 확장자가 비디오 파일이 아닌 경우 건너뛰기
        if not video_filepath.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
            continue

        output_video_path = os.path.join(output_base_dir, f"processed_{filename}")
        csv_path = os.path.join(csv_output_base_dir, f"{filename}.csv")

        try:
            # 비디오 파일 로드
            clip = VideoFileClip(video_filepath)

            # 비디오 라이터 초기화
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_video_path, fourcc, clip.fps, (int(clip.w), int(clip.h)))

            # 현재 비디오 파일에 대한 결과를 저장할 리스트 초기화
            current_video_results = []

            # 클립에서 프레임 단위로 처리
            frame_count = 0
            for frame in clip.iter_frames(fps=clip.fps):
                frame_bgr = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
                results = model(frame_bgr)

                # YOLO 모델이 제대로 객체를 감지하는지 확인
                print(f"Frame {frame_count}: Detected {len(results[0].boxes)} objects")

                landmarks = process_frame(frame_bgr, results[0].boxes)
                if landmarks:
                    row = {
                        'filename': filename,
                        'frame': frame_count,
                        'behavior': behavior,
                    }
                    for i, (x, y, z, vis) in enumerate(landmarks):
                        row[f'landmark_{i}_x'] = x
                        row[f'landmark_{i}_y'] = y
                        row[f'landmark_{i}_z'] = z
                        row[f'landmark_{i}_vis'] = vis
                    current_video_results.append(row)

                    cv2.putText(frame_bgr, behavior, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)

                # 결과를 비디오에 작성
                out.write(frame_bgr)
                frame_count += 1

            # 현재 비디오 파일에 대한 결과를 전체 결과 리스트에 추가
            results_list.extend(current_video_results)

            # CSV 파일 생성 (현재 비디오 파일에 대한 결과)
            results_df = pd.DataFrame(current_video_results)
            results_df.to_csv(csv_path, index=False)

            # 리소스 해제
            out.release()
            clip.reader.close()
            if clip.audio is not None:
                clip.audio.reader.close_proc()

        except Exception as e:
            print(f"Error processing file {video_filepath}: {e}")

print("모든 클립 처리 완료!")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 0: 384x640 1 person, 1 handbag, 6 bottles, 1 tv, 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46: Detected 9 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 apple, 1 tv, 12.5ms
# Speed: 3.4ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 7 bottles, 1 apple, 1 tv, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 apple, 1 tv, 15.5ms
# Speed: 5.4ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49: Detected 13 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 tv, 16.7ms
# Speed: 3.2ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50: Detected 11 objects
#
# 0: 384x640 2 persons, 1 handbag, 9 bottles, 1 tv, 13.4ms
# Speed: 7.8ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51: Detected 13 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 tv, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 7 bottles, 1 tv, 10.7ms
# Speed: 12.9ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53: Detected 10 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 apple, 1 tv, 17.2ms
# Speed: 3.2ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54: Detected 13 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 apple, 1 tv, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55: Detected 13 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 apple, 1 tv, 13.6ms
# Speed: 4.3ms preprocess, 13.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56: Detected 13 objects
#
# 0: 384x640 1 person, 9 bottles, 1 apple, 1 tv, 11.2ms
# Speed: 4.7ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57: Detected 12 objects
#
# 0: 384x640 1 person, 9 bottles, 1 apple, 1 tv, 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58: Detected 12 objects
#
# 0: 384x640 1 person, 9 bottles, 1 apple, 19.2ms
# Speed: 5.1ms preprocess, 19.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 apple, 1 tv, 11.2ms
# Speed: 9.0ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 apple, 1 tv, 16.0ms
# Speed: 6.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61: Detected 11 objects
#
# 0: 384x640 1 person, 9 bottles, 1 apple, 1 tv, 11.5ms
# Speed: 3.9ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62: Detected 12 objects
#
# 0: 384x640 1 person, 8 bottles, 1 apple, 1 tv, 13.3ms
# Speed: 4.0ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 apple, 1 tv, 13.2ms
# Speed: 6.0ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 apple, 1 tv, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 11.3ms
# Speed: 7.5ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66: Detected 9 objects
#
# 0: 384x640 1 person, 8 bottles, 1 tv, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67: Detected 10 objects
#
# 0: 384x640 1 person, 7 bottles, 1 banana, 1 tv, 20.7ms
# Speed: 8.8ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68: Detected 10 objects
#
# 0: 384x640 1 person, 9 bottles, 1 tv, 16.4ms
# Speed: 5.3ms preprocess, 16.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69: Detected 11 objects
#
# 0: 384x640 1 person, 9 bottles, 1 tv, 16.4ms
# Speed: 5.6ms preprocess, 16.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 70: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 tv, 13.6ms
# Speed: 6.2ms preprocess, 13.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 71: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 tv, 10.8ms
# Speed: 4.8ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 72: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 tv, 18.2ms
# Speed: 4.0ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 73: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 tv, 22.0ms
# Speed: 3.5ms preprocess, 22.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 74: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 tv, 10.8ms
# Speed: 5.4ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 75: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 tv, 16.0ms
# Speed: 5.1ms preprocess, 16.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 76: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 tv, 1 book, 10.7ms
# Speed: 3.9ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 77: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 9 bottles, 1 apple, 1 tv, 16.3ms
# Speed: 5.2ms preprocess, 16.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 78: Detected 13 objects
#
# 0: 384x640 1 person, 9 bottles, 1 tv, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 79: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 tv, 17.0ms
# Speed: 12.3ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 80: Detected 10 objects
#
# 0: 384x640 1 person, 8 bottles, 1 tv, 13.8ms
# Speed: 3.3ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 81: Detected 10 objects
#
# 0: 384x640 1 person, 7 bottles, 1 tv, 10.7ms
# Speed: 7.3ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 82: Detected 9 objects
#
# 0: 384x640 1 person, 9 bottles, 1 tv, 11.4ms
# Speed: 3.2ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 83: Detected 11 objects
#
# 0: 384x640 1 person, 9 bottles, 1 tv, 12.6ms
# Speed: 5.5ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 84: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 tv, 14.7ms
# Speed: 5.9ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 85: Detected 10 objects
#
# 0: 384x640 1 person, 8 bottles, 1 apple, 1 tv, 14.9ms
# Speed: 6.1ms preprocess, 14.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 86: Detected 11 objects
#
# 0: 384x640 1 person, 8 bottles, 1 tv, 11.4ms
# Speed: 8.2ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 87: Detected 10 objects
#
# 0: 384x640 1 person, 1 handbag, 7 bottles, 1 tv, 10.8ms
# Speed: 6.2ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 88: Detected 10 objects
#
# 0: 384x640 1 person, 1 handbag, 7 bottles, 1 apple, 1 tv, 15.1ms
# Speed: 7.9ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 89: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 tv, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 90: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 apple, 13.2ms
# Speed: 3.6ms preprocess, 13.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 91: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 7 bottles, 1 tv, 1 book, 11.7ms
# Speed: 3.8ms preprocess, 11.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 92: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 tv, 16.6ms
# Speed: 4.1ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 93: Detected 11 objects
#
# 0: 384x640 1 person, 1 handbag, 8 bottles, 1 apple, 1 tv, 11.1ms
# Speed: 4.6ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 94: Detected 12 objects
#
# 0: 384x640 1 person, 1 handbag, 7 bottles, 1 apple, 1 tv, 13.9ms
# Speed: 4.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 95: Detected 11 objects
#
# 0: 384x640 1 person, 1 bottle, 25.6ms
# Speed: 8.5ms preprocess, 25.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 0: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 13.2ms
# Speed: 3.1ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1: Detected 2 objects
#
# 0: 384x640 1 person, 22.5ms
# Speed: 3.9ms preprocess, 22.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2: Detected 1 objects
#
# 0: 384x640 1 person, 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 9.0ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 12.1ms
# Speed: 3.4ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 18.3ms
# Speed: 3.3ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 12.4ms
# Speed: 8.1ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10: Detected 2 objects
#
# 0: 384x640 1 person, 18.1ms
# Speed: 3.4ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11: Detected 1 objects
#
# 0: 384x640 1 person, 11.0ms
# Speed: 5.4ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12: Detected 1 objects
#
# 0: 384x640 1 person, 22.6ms
# Speed: 7.3ms preprocess, 22.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13: Detected 1 objects
#
# 0: 384x640 1 person, 10.6ms
# Speed: 7.7ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14: Detected 1 objects
#
# 0: 384x640 1 person, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15: Detected 1 objects
#
# 0: 384x640 1 person, 11.1ms
# Speed: 4.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 7.0ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17: Detected 1 objects
#
# 0: 384x640 1 person, 17.3ms
# Speed: 3.7ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18: Detected 1 objects
#
# 0: 384x640 1 person, 13.6ms
# Speed: 6.5ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19: Detected 1 objects
#
# 0: 384x640 1 person, 16.3ms
# Speed: 8.9ms preprocess, 16.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20: Detected 1 objects
#
# 0: 384x640 1 person, 18.6ms
# Speed: 3.4ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21: Detected 1 objects
#
# 0: 384x640 1 person, 11.0ms
# Speed: 3.2ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 3.3ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 6.5ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24: Detected 1 objects
#
# 0: 384x640 1 person, 13.3ms
# Speed: 3.1ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25: Detected 1 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26: Detected 1 objects
#
# 0: 384x640 1 person, 11.2ms
# Speed: 7.8ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27: Detected 1 objects
#
# 0: 384x640 1 person, 13.8ms
# Speed: 6.3ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28: Detected 1 objects
#
# 0: 384x640 1 person, 27.1ms
# Speed: 8.4ms preprocess, 27.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29: Detected 1 objects
#
# 0: 384x640 1 person, 20.3ms
# Speed: 12.8ms preprocess, 20.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31: Detected 1 objects
#
# 0: 384x640 1 person, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32: Detected 1 objects
#
# 0: 384x640 1 person, 23.9ms
# Speed: 3.6ms preprocess, 23.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33: Detected 1 objects
#
# 0: 384x640 1 person, 13.8ms
# Speed: 3.4ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34: Detected 1 objects
#
# 0: 384x640 1 person, 11.1ms
# Speed: 3.3ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35: Detected 1 objects
#
# 0: 384x640 1 person, 23.8ms
# Speed: 7.2ms preprocess, 23.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36: Detected 1 objects
#
# 0: 384x640 1 person, 32.9ms
# Speed: 8.1ms preprocess, 32.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37: Detected 1 objects
#
# 0: 384x640 1 person, 18.7ms
# Speed: 7.1ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38: Detected 1 objects
#
# 0: 384x640 1 person, 11.1ms
# Speed: 3.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39: Detected 1 objects
#
# 0: 384x640 1 person, 18.3ms
# Speed: 3.7ms preprocess, 18.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40: Detected 1 objects
#
# 0: 384x640 1 person, 19.4ms
# Speed: 3.2ms preprocess, 19.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41: Detected 1 objects
#
# 0: 384x640 1 person, 28.9ms
# Speed: 6.6ms preprocess, 28.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42: Detected 1 objects
#
# 0: 384x640 1 person, 24.9ms
# Speed: 12.1ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43: Detected 1 objects
#
# 0: 384x640 1 person, 11.3ms
# Speed: 3.3ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44: Detected 1 objects
#
# 0: 384x640 1 person, 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45: Detected 1 objects
#
# 0: 384x640 1 person, 18.9ms
# Speed: 3.9ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46: Detected 1 objects
#
# 0: 384x640 1 person, 25.9ms
# Speed: 3.3ms preprocess, 25.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47: Detected 1 objects
#
# 0: 384x640 1 person, 15.2ms
# Speed: 3.3ms preprocess, 15.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48: Detected 1 objects
#
# 0: 384x640 1 person, 18.7ms
# Speed: 3.2ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49: Detected 1 objects
#
# 0: 384x640 1 person, 23.0ms
# Speed: 10.3ms preprocess, 23.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50: Detected 1 objects
#
# 0: 384x640 1 person, 21.9ms
# Speed: 7.2ms preprocess, 21.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51: Detected 1 objects
#
# 0: 384x640 1 person, 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52: Detected 1 objects
#
# 0: 384x640 1 person, 15.7ms
# Speed: 4.3ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53: Detected 1 objects
#
# 0: 384x640 1 person, 12.1ms
# Speed: 11.4ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54: Detected 1 objects
#
# 0: 384x640 1 person, 15.1ms
# Speed: 8.7ms preprocess, 15.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55: Detected 1 objects
#
# 0: 384x640 1 person, 23.5ms
# Speed: 4.8ms preprocess, 23.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56: Detected 1 objects
#
# 0: 384x640 1 person, 20.6ms
# Speed: 3.0ms preprocess, 20.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57: Detected 1 objects
#
# 0: 384x640 1 person, 17.1ms
# Speed: 5.1ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58: Detected 1 objects
#
# 0: 384x640 1 person, 19.2ms
# Speed: 6.0ms preprocess, 19.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59: Detected 1 objects
#
# 0: 384x640 1 person, 19.5ms
# Speed: 4.7ms preprocess, 19.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60: Detected 1 objects
#
# 0: 384x640 1 person, 25.4ms
# Speed: 3.2ms preprocess, 25.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61: Detected 1 objects
#
# 0: 384x640 1 person, 19.7ms
# Speed: 5.7ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62: Detected 1 objects
#
# 0: 384x640 1 person, 29.3ms
# Speed: 3.0ms preprocess, 29.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63: Detected 1 objects
#
# 0: 384x640 1 person, 25.2ms
# Speed: 7.9ms preprocess, 25.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64: Detected 1 objects
#
# 0: 384x640 1 person, 21.6ms
# Speed: 5.1ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65: Detected 1 objects
#
# 0: 384x640 1 person, 23.0ms
# Speed: 5.9ms preprocess, 23.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66: Detected 1 objects
#
# 0: 384x640 1 person, 25.6ms
# Speed: 3.1ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67: Detected 1 objects
#
# 0: 384x640 1 person, 13.8ms
# Speed: 3.1ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68: Detected 1 objects
#
# 0: 384x640 1 person, 21.5ms
# Speed: 8.7ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69: Detected 1 objects
#
# 0: 384x640 1 person, 19.2ms
# Speed: 3.2ms preprocess, 19.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 70: Detected 1 objects
#
# 0: 384x640 1 person, 19.7ms
# Speed: 7.4ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 71: Detected 1 objects
#
# 0: 384x640 1 person, 25.2ms
# Speed: 7.4ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 72: Detected 1 objects
#
# 0: 384x640 1 person, 13.8ms
# Speed: 12.4ms preprocess, 13.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 73: Detected 1 objects
#
# 0: 384x640 1 person, 20.2ms
# Speed: 3.3ms preprocess, 20.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 74: Detected 1 objects
#
# 0: 384x640 1 person, 20.2ms
# Speed: 4.0ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 75: Detected 1 objects
#
# 0: 384x640 1 person, 28.1ms
# Speed: 3.3ms preprocess, 28.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 76: Detected 1 objects
#
# 0: 384x640 1 person, 11.8ms
# Speed: 3.2ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 77: Detected 1 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 6.8ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 78: Detected 1 objects
#
# 0: 384x640 1 person, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 79: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 17.2ms
# Speed: 7.7ms preprocess, 17.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 80: Detected 2 objects
#
# 0: 384x640 1 person, 12.4ms
# Speed: 5.2ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 81: Detected 1 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 3.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 82: Detected 1 objects
#
# 0: 384x640 1 person, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 83: Detected 1 objects
#
# 0: 384x640 1 person, 11.6ms
# Speed: 3.5ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 84: Detected 1 objects
#
# 0: 384x640 1 person, 11.7ms
# Speed: 3.3ms preprocess, 11.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 85: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 4.1ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 86: Detected 1 objects
#
# 0: 384x640 1 person, 3 backpacks, 11.0ms
# Speed: 9.0ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 0: Detected 4 objects
#
# 0: 384x640 1 person, 2 backpacks, 14.5ms
# Speed: 15.8ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1: Detected 3 objects
#
# 0: 384x640 1 person, 2 backpacks, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2: Detected 3 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 10.9ms
# Speed: 3.7ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 14.1ms
# Speed: 3.5ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4: Detected 2 objects
#
# 0: 384x640 1 person, 11.2ms
# Speed: 3.4ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5: Detected 1 objects
#
# 0: 384x640 1 person, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6: Detected 1 objects
#
# 0: 384x640 2 persons, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7: Detected 2 objects
#
# 0: 384x640 1 person, 14.4ms
# Speed: 7.1ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8: Detected 1 objects
#
# 0: 384x640 1 person, 1 handbag, 12.3ms
# Speed: 3.3ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9: Detected 2 objects
#
# 0: 384x640 1 person, 15.6ms
# Speed: 10.3ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10: Detected 1 objects
#
# 0: 384x640 1 person, 26.5ms
# Speed: 8.2ms preprocess, 26.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11: Detected 1 objects
#
# 0: 384x640 1 person, 14.4ms
# Speed: 7.4ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 8.7ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15: Detected 2 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16: Detected 1 objects
#
# 0: 384x640 1 person, 11.7ms
# Speed: 3.3ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17: Detected 1 objects
#
# 0: 384x640 1 person, 16.8ms
# Speed: 3.3ms preprocess, 16.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18: Detected 1 objects
#
# 0: 384x640 1 person, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19: Detected 1 objects
#
# 0: 384x640 1 person, 18.7ms
# Speed: 10.0ms preprocess, 18.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20: Detected 1 objects
#
# 0: 384x640 1 person, 19.3ms
# Speed: 8.1ms preprocess, 19.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21: Detected 1 objects
#
# 0: 384x640 1 person, 11.0ms
# Speed: 4.2ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22: Detected 1 objects
#
# 0: 384x640 1 person, 27.1ms
# Speed: 6.4ms preprocess, 27.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23: Detected 1 objects
#
# 0: 384x640 1 person, 39.2ms
# Speed: 11.3ms preprocess, 39.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24: Detected 1 objects
#
# 0: 384x640 1 person, 18.1ms
# Speed: 3.5ms preprocess, 18.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25: Detected 1 objects
#
# 0: 384x640 1 person, 17.3ms
# Speed: 3.4ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 20.0ms
# Speed: 5.6ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27: Detected 2 objects
#
# 0: 384x640 1 person, 11.1ms
# Speed: 3.6ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28: Detected 1 objects
#
# 0: 384x640 1 person, 10.9ms
# Speed: 4.2ms preprocess, 10.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 11.7ms
# Speed: 3.6ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 12.2ms
# Speed: 10.6ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33: Detected 2 objects
#
# 0: 384x640 1 person, 10.9ms
# Speed: 3.7ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34: Detected 1 objects
#
# 0: 384x640 1 person, 13.6ms
# Speed: 3.5ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 11.5ms
# Speed: 3.3ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36: Detected 2 objects
#
# 0: 384x640 1 person, 20.2ms
# Speed: 5.2ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37: Detected 1 objects
#
# 0: 384x640 1 person, 10.9ms
# Speed: 6.0ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38: Detected 1 objects
#
# 0: 384x640 1 person, 12.9ms
# Speed: 9.4ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39: Detected 1 objects
#
# 0: 384x640 1 person, 13.0ms
# Speed: 4.6ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 18.9ms
# Speed: 5.1ms preprocess, 18.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41: Detected 2 objects
#
# 0: 384x640 1 person, 13.4ms
# Speed: 7.5ms preprocess, 13.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 9.9ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43: Detected 1 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44: Detected 1 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45: Detected 1 objects
#
# 0: 384x640 1 person, 16.2ms
# Speed: 3.2ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46: Detected 1 objects
#
# 0: 384x640 1 person, 1 handbag, 19.0ms
# Speed: 5.3ms preprocess, 19.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 19.1ms
# Speed: 9.6ms preprocess, 19.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48: Detected 2 objects
#
# 0: 384x640 1 person, 11.5ms
# Speed: 3.4ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49: Detected 1 objects
#
# 0: 384x640 1 person, 13.3ms
# Speed: 3.9ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 13.1ms
# Speed: 9.3ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 17.6ms
# Speed: 15.0ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53: Detected 2 objects
#
# 0: 384x640 1 person, 1 cup, 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54: Detected 2 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55: Detected 1 objects
#
# 0: 384x640 1 person, 11.9ms
# Speed: 3.4ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 18.4ms
# Speed: 8.0ms preprocess, 18.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 11.5ms
# Speed: 5.7ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 23.8ms
# Speed: 3.3ms preprocess, 23.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60: Detected 3 objects
#
# 0: 384x640 1 person, 23.7ms
# Speed: 5.7ms preprocess, 23.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61: Detected 1 objects
#
# 0: 384x640 1 person, 14.4ms
# Speed: 4.2ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62: Detected 1 objects
#
# 0: 384x640 1 person, 16.4ms
# Speed: 3.5ms preprocess, 16.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63: Detected 1 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 16.7ms
# Speed: 3.1ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 21.6ms
# Speed: 3.3ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 21.3ms
# Speed: 4.4ms preprocess, 21.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66: Detected 2 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 3.3ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68: Detected 1 objects
#
# 0: 384x640 1 person, 11.5ms
# Speed: 3.1ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69: Detected 1 objects
#
# 0: 384x640 1 person, 11.2ms
# Speed: 5.1ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 70: Detected 1 objects
#
# 0: 384x640 1 person, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 71: Detected 1 objects
#
# 0: 384x640 1 person, 10.8ms
# Speed: 7.0ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 72: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 12.0ms
# Speed: 3.8ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 73: Detected 2 objects
#
# 0: 384x640 1 person, 3 handbags, 1 bottle, 11.8ms
# Speed: 3.7ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 74: Detected 5 objects
#
# 0: 384x640 1 person, 1 bottle, 17.9ms
# Speed: 10.0ms preprocess, 17.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 75: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 11.5ms
# Speed: 4.1ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 76: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 77: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 78: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 12.4ms
# Speed: 8.0ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 79: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 11.5ms
# Speed: 4.1ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 80: Detected 3 objects
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 12.9ms
# Speed: 7.2ms preprocess, 12.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 0: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 20.4ms
# Speed: 6.4ms preprocess, 20.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 15.6ms
# Speed: 4.5ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 1 donut, 17.8ms
# Speed: 5.6ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4: Detected 5 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 24.3ms
# Speed: 4.4ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 18.1ms
# Speed: 8.8ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 14.2ms
# Speed: 12.8ms preprocess, 14.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 24.1ms
# Speed: 3.4ms preprocess, 24.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8: Detected 3 objects
#
# 0: 384x640 1 person, 2 handbags, 1 bottle, 13.2ms
# Speed: 4.2ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9: Detected 4 objects
#
# 0: 384x640 1 person, 2 handbags, 1 bottle, 20.9ms
# Speed: 5.4ms preprocess, 20.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10: Detected 4 objects
#
# 0: 384x640 1 person, 2 handbags, 1 bottle, 15.0ms
# Speed: 6.4ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 21.6ms
# Speed: 3.2ms preprocess, 21.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12: Detected 3 objects
#
# 0: 384x640 2 persons, 1 backpack, 1 handbag, 26.4ms
# Speed: 6.2ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13: Detected 4 objects
#
# 0: 384x640 1 person, 1 backpack, 16.9ms
# Speed: 3.2ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14: Detected 2 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 10.9ms
# Speed: 5.9ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 1 donut, 19.9ms
# Speed: 4.2ms preprocess, 19.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16: Detected 5 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 2 bottles, 1 donut, 21.2ms
# Speed: 3.2ms preprocess, 21.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17: Detected 6 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 1 donut, 18.7ms
# Speed: 4.1ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18: Detected 5 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 1 donut, 15.6ms
# Speed: 5.2ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19: Detected 5 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 1 donut, 23.3ms
# Speed: 3.1ms preprocess, 23.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20: Detected 5 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 2 bottles, 1 donut, 26.4ms
# Speed: 3.2ms preprocess, 26.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21: Detected 6 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 1 donut, 16.8ms
# Speed: 5.2ms preprocess, 16.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22: Detected 5 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 1 donut, 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23: Detected 4 objects
#
# 0: 384x640 1 person, 1 bottle, 24.5ms
# Speed: 9.7ms preprocess, 24.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 1 donut, 24.5ms
# Speed: 4.9ms preprocess, 24.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 11.0ms
# Speed: 3.4ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26: Detected 2 objects
#
# 0: 384x640 1 person, 1 backpack, 22.4ms
# Speed: 3.2ms preprocess, 22.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27: Detected 2 objects
#
# 0: 384x640 1 person, 1 backpack, 18.8ms
# Speed: 5.1ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28: Detected 2 objects
#
# 0: 384x640 1 person, 19.5ms
# Speed: 4.9ms preprocess, 19.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 16.6ms
# Speed: 4.1ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 16.2ms
# Speed: 10.2ms preprocess, 16.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 28.1ms
# Speed: 8.4ms preprocess, 28.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 21.0ms
# Speed: 3.2ms preprocess, 21.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 24.2ms
# Speed: 6.3ms preprocess, 24.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34: Detected 4 objects
#
# 0: 384x640 1 person, 1 bottle, 12.6ms
# Speed: 4.7ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 18.8ms
# Speed: 4.3ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 23.2ms
# Speed: 4.3ms preprocess, 23.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 18.5ms
# Speed: 7.8ms preprocess, 18.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 12.8ms
# Speed: 3.2ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39: Detected 3 objects
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 21.5ms
# Speed: 12.0ms preprocess, 21.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 16.8ms
# Speed: 5.6ms preprocess, 16.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 20.5ms
# Speed: 5.0ms preprocess, 20.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42: Detected 4 objects
#
# 0: 384x640 1 person, 2 bottles, 16.7ms
# Speed: 7.8ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 25.5ms
# Speed: 3.4ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 22.2ms
# Speed: 6.6ms preprocess, 22.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 17.1ms
# Speed: 3.9ms preprocess, 17.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 14.0ms
# Speed: 3.9ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 23.2ms
# Speed: 4.0ms preprocess, 23.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 16.8ms
# Speed: 6.1ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 14.0ms
# Speed: 4.2ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 22.3ms
# Speed: 3.2ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 12.7ms
# Speed: 3.3ms preprocess, 12.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 11.9ms
# Speed: 6.4ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 13.6ms
# Speed: 3.2ms preprocess, 13.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 11.4ms
# Speed: 6.0ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 10.7ms
# Speed: 4.6ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 19.8ms
# Speed: 3.5ms preprocess, 19.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 12.2ms
# Speed: 3.7ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58: Detected 2 objects
#
# 0: 384x640 1 person, 2 bottles, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 11.3ms
# Speed: 4.3ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 14.8ms
# Speed: 8.5ms preprocess, 14.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 13.5ms
# Speed: 5.4ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 14.1ms
# Speed: 8.0ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 14.4ms
# Speed: 11.4ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 14.5ms
# Speed: 4.6ms preprocess, 14.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 17.5ms
# Speed: 5.0ms preprocess, 17.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67: Detected 2 objects
#
# 0: 384x640 1 person, 2 bottles, 10.9ms
# Speed: 4.1ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 12.1ms
# ...
# Frame 96: Detected 9 objects
#
# 0: 384x640 1 person, 1 umbrella, 1 handbag, 1 suitcase, 6 bottles, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 97: Detected 10 objects
#
# 0: 384x640 1 person, 1 suitcase, 6 bottles, 1 tv, 11.1ms
# Speed: 6.6ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 98: Detected 9 objects
#
# 0: 384x640 1 person, 3 bottles, 17.4ms
# Speed: 3.9ms preprocess, 17.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 0: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 11.3ms
# Speed: 11.8ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 1 donut, 11.7ms
# Speed: 5.1ms preprocess, 11.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 1 donut, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 1 donut, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 1 chair, 1 tv, 10.9ms
# Speed: 10.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5: Detected 6 objects
#
# 0: 384x640 1 person, 3 bottles, 10.7ms
# Speed: 3.3ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6: Detected 4 objects
#
# 0: 384x640 1 person, 1 suitcase, 3 bottles, 1 tv, 20.6ms
# Speed: 3.3ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7: Detected 6 objects
#
# 0: 384x640 1 person, 3 bottles, 1 tv, 12.7ms
# Speed: 4.5ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 1 tv, 12.6ms
# Speed: 3.3ms preprocess, 12.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 11.4ms
# Speed: 3.4ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10: Detected 4 objects
#
# 0: 384x640 1 person, 1 suitcase, 3 bottles, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11: Detected 5 objects
#
# 0: 384x640 1 person, 1 suitcase, 2 bottles, 1 tv, 12.4ms
# Speed: 3.2ms preprocess, 12.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12: Detected 5 objects
#
# 0: 384x640 1 person, 1 suitcase, 3 bottles, 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13: Detected 5 objects
#
# 0: 384x640 1 person, 1 suitcase, 3 bottles, 10.6ms
# Speed: 13.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14: Detected 5 objects
#
# 0: 384x640 1 person, 1 suitcase, 3 bottles, 13.8ms
# Speed: 3.7ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15: Detected 5 objects
#
# 0: 384x640 2 persons, 3 bottles, 14.5ms
# Speed: 6.8ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16: Detected 5 objects
#
# 0: 384x640 1 person, 2 bottles, 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 16.3ms
# Speed: 3.3ms preprocess, 16.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 19.0ms
# Speed: 4.1ms preprocess, 19.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19: Detected 2 objects
#
# 0: 384x640 1 person, 1 skateboard, 2 bottles, 18.9ms
# Speed: 4.2ms preprocess, 18.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20: Detected 4 objects
#
# 0: 384x640 1 person, 2 bottles, 11.3ms
# Speed: 3.4ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21: Detected 3 objects
#
# 0: 384x640 1 person, 1 skateboard, 1 bottle, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23: Detected 3 objects
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24: Detected 3 objects
#
# 0: 384x640 1 person, 3 bottles, 1 tv, 12.1ms
# Speed: 3.2ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 1 tv, 12.7ms
# Speed: 3.9ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26: Detected 5 objects
#
# 0: 384x640 1 person, 2 skateboards, 3 bottles, 11.0ms
# Speed: 3.4ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27: Detected 6 objects
#
# 0: 384x640 1 person, 1 skateboard, 2 bottles, 17.4ms
# Speed: 14.4ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28: Detected 4 objects
#
# 0: 384x640 1 person, 1 skateboard, 3 bottles, 11.5ms
# Speed: 3.4ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29: Detected 5 objects
#
# 0: 384x640 1 person, 1 skateboard, 3 bottles, 19.0ms
# Speed: 3.2ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30: Detected 5 objects
#
# 0: 384x640 1 person, 2 bottles, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 28.6ms
# Speed: 5.8ms preprocess, 28.6ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32: Detected 3 objects
#
# 0: 384x640 2 persons, 2 bottles, 21.5ms
# Speed: 7.6ms preprocess, 21.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33: Detected 4 objects
#
# 0: 384x640 1 person, 1 suitcase, 2 bottles, 17.7ms
# Speed: 5.7ms preprocess, 17.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34: Detected 4 objects
#
# 0: 384x640 1 person, 2 bottles, 13.5ms
# Speed: 8.8ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35: Detected 3 objects
#
# 0: 384x640 1 person, 1 suitcase, 3 bottles, 14.5ms
# Speed: 4.5ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36: Detected 5 objects
#
# 0: 384x640 1 person, 2 bottles, 14.9ms
# Speed: 7.3ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 11.2ms
# Speed: 4.1ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38: Detected 3 objects
#
# 0: 384x640 1 person, 1 skateboard, 3 bottles, 11.4ms
# Speed: 3.3ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 18.5ms
# Speed: 3.2ms preprocess, 18.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 12.2ms
# Speed: 9.7ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 13.5ms
# Speed: 3.8ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42: Detected 4 objects
#
# 0: 384x640 1 person, 1 skateboard, 3 bottles, 15.3ms
# Speed: 3.3ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43: Detected 5 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 10.7ms
# Speed: 3.5ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 18.0ms
# Speed: 7.5ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46: Detected 4 objects
#
# 0: 384x640 1 person, 3 bottles, 21.9ms
# Speed: 7.3ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47: Detected 4 objects
#
# 0: 384x640 1 person, 1 backpack, 1 bottle, 18.5ms
# Speed: 3.8ms preprocess, 18.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 13.7ms
# Speed: 3.4ms preprocess, 13.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 11.5ms
# Speed: 5.0ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 11.3ms
# Speed: 3.4ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51: Detected 3 objects
#
# 0: 384x640 1 person, 2 bottles, 14.3ms
# Speed: 3.3ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52: Detected 3 objects
#
# 0: 384x640 1 person, 1 umbrella, 2 bottles, 1 tv, 26.5ms
# Speed: 3.7ms preprocess, 26.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53: Detected 5 objects
#
# 0: 384x640 1 person, 2 bottles, 16.8ms
# Speed: 7.7ms preprocess, 16.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54: Detected 3 objects
#
# 0: 384x640 1 person, 1 umbrella, 2 bottles, 24.0ms
# Speed: 3.5ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55: Detected 4 objects
#
# 0: 384x640 1 person, 16.0ms
# Speed: 3.4ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56: Detected 1 objects
#
# 0: 384x640 1 person, 1 bottle, 12.1ms
# Speed: 3.3ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57: Detected 2 objects
#
# 0: 384x640 1 person, 1 backpack, 4 bottles, 11.6ms
# Speed: 4.2ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58: Detected 6 objects
#
# 0: 384x640 2 persons, 1 handbag, 2 bottles, 10.7ms
# Speed: 5.3ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59: Detected 5 objects
#
# 0: 384x640 1 person, 1 bottle, 14.7ms
# Speed: 6.6ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 11.6ms
# Speed: 6.8ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 11.6ms
# Speed: 3.8ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62: Detected 2 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 2 bottles, 15.6ms
# Speed: 8.4ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63: Detected 5 objects
#
# 0: 384x640 1 person, 1 suitcase, 2 bottles, 14.3ms
# Speed: 10.0ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64: Detected 4 objects
#
# 0: 384x640 1 person, 1 bottle, 19.1ms
# Speed: 4.2ms preprocess, 19.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65: Detected 2 objects
#
# 0: 384x640 1 person, 1 bottle, 18.8ms
# Speed: 5.4ms preprocess, 18.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66: Detected 2 objects
#
# 0: 384x640 1 person, 1 backpack, 1 bottle, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67: Detected 3 objects
#
# 0: 384x640 2 persons, 1 backpack, 1 bottle, 12.7ms
# Speed: 8.7ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68: Detected 4 objects
#
# 0: 384x640 1 person, 1 backpack, 1 bottle, 14.0ms
# Speed: 8.9ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69: Detected 3 objects
#
# 0: 384x640 1 person, 4 bottles, 10.9ms
# Speed: 8.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 70: Detected 5 objects
#
# 0: 384x640 1 person, 3 bottles, 11.5ms
# Speed: 3.3ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 71: Detected 4 objects
#
# 0: 384x640 2 persons, 1 suitcase, 1 bottle, 11.9ms
# Speed: 3.5ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 72: Detected 4 objects
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 12.4ms
# Speed: 3.3ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 73: Detected 3 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 19.0ms
# Speed: 7.4ms preprocess, 19.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 74: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 2 bottles, 18.9ms
# Speed: 3.2ms preprocess, 18.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 75: Detected 4 objects
#
# 0: 384x640 1 person, 2 bottles, 23.1ms
# Speed: 5.2ms preprocess, 23.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 76: Detected 3 objects
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 24.4ms
# Speed: 5.8ms preprocess, 24.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 77: Detected 3 objects
#
# 0: 384x640 1 person, 3 suitcases, 1 bottle, 14.2ms
# Speed: 3.1ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 78: Detected 5 objects
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 79: Detected 3 objects
#
# 0: 384x640 1 person, 2 suitcases, 1 bottle, 20.6ms
# Speed: 3.3ms preprocess, 20.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 80: Detected 4 objects
#
# 0: 384x640 1 person, 2 suitcases, 2 bottles, 18.3ms
# Speed: 7.4ms preprocess, 18.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 81: Detected 5 objects
#
# 0: 384x640 1 person, 1 backpack, 1 suitcase, 2 bottles, 18.4ms
# Speed: 7.2ms preprocess, 18.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 82: Detected 5 objects
#
# 0: 384x640 2 persons, 1 bottle, 23.2ms
# Speed: 3.2ms preprocess, 23.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 83: Detected 3 objects
#
# 0: 384x640 1 person, 2 suitcases, 1 bottle, 23.8ms
# Speed: 3.2ms preprocess, 23.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 84: Detected 4 objects
#
# 0: 384x640 1 person, 1 handbag, 1 suitcase, 1 bottle, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 85: Detected 4 objects
#
# 0: 384x640 1 person, 2 bottles, 1 tv, 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 86: Detected 4 objects
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 10.9ms
# Speed: 6.0ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 87: Detected 3 objects
#
# 0: 384x640 1 person, 1 suitcase, 1 bottle, 11.9ms
# Speed: 3.3ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 88: Detected 3 objects
#
# 0: 384x640 1 person, 2 suitcases, 1 bottle, 16.2ms
# Speed: 5.1ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 89: Detected 4 objects
# 모든 클립 처리 완료!
